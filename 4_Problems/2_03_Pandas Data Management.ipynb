# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/lukebarousse/Python_Data_Analytics_Course/blob/main/4_Problems/2_03_Pandas Data Management.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %%
# Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt  

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %% [markdown]
# ## 🟩 Drop Missing Values (2.3.1)

# %%
# Problem Statement:
# Create a copy of the DataFrame and drop rows where the salary_year_avg column has missing values. Display the first 5 rows of the cleaned DataFrame.

# %%
df_copy=df.copy()
df_copy.salary_year_avg.dropna().head(5)
df_copy.dropna(subset='salary_year_avg').head(5)
# Out:
#     job_title_short                                job_title  \
# 28   Data Scientist                      CRM Data Specialist
# 77    Data Engineer                            Data Engineer
# 92    Data Engineer  Remote - Data Engineer - Permanent - W2
# 100  Data Scientist  Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst    Senior Supply Chain Analytics Analyst
#
#                                 job_location          job_via  \
# 28   San José Province, San José, Costa Rica  via Ai-Jobs.net
# 77                             Arlington, VA     via LinkedIn
# 92                                  Anywhere     via LinkedIn
# 100                        Mountain View, CA     via LinkedIn
# 109                                 Anywhere       via Get.It
#
#     job_schedule_type  job_work_from_home            search_location  \
# 28          Full-time               False                 Costa Rica
# 77          Full-time               False                      Sudan
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟩 Random Sample of DataFrame (2.3.2)

# %%
# Problem Statement:
# Create a new DataFrame that is a random sample of 10% of the original DataFrame. Display the first 5 rows of the sampled DataFrame.

# %%
df_copy=df.sample(frac=0.1)
df_copy.head()
# Out:
#          job_title_short                    job_title         job_location  \
# 293385     Data Engineer  Data Engineer – Web Scraper            Leeds, UK
# 165214      Data Analyst      Senior Privacy Engineer            Australia
# 288507    Cloud Engineer            Customer Engineer       Kraków, Poland
# 746846  Business Analyst                   HR Analyst     Jacksonville, FL
# 160754     Data Engineer          Azure Data Engineer  Toronto, ON, Canada
#
#                     job_via job_schedule_type  job_work_from_home  \
# 293385          via Harnham         Full-time               False
# 165214  via BeBee Australia         Full-time               False
# 288507            via BeBee         Full-time               False
# 746846         via LinkedIn         Full-time               False
# 160754         via LinkedIn        Contractor               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## 🟨 Fill Missing Salaries (2.3.3)

# %%
# Problem Statement:
# Create a copy of the original DataFrame and fill in missing values in the salary_year_avg column with the median salary. 
# Display the first 5 rows of the altered DataFrame.

# %%
df_copy=df.copy()
median_salary=df.salary_year_avg.median()
df_copy.salary_year_avg.fillna(median_salary,inplace=True)
df_copy.head()
# Out:
# /var/folders/tt/qfxycl216j58dvqnhjchgxyc0000gq/T/ipykernel_1395/3075745707.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_copy.salary_year_avg.fillna(median_salary,inplace=True)
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# ...

# %%
df_copy = df.copy()
median_salary = df_copy['salary_year_avg'].median()
df_copy['salary_year_avg'] = df_copy['salary_year_avg'].fillna(median_salary)
df_copy.head(5)
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# ...

# %% [markdown]
# ---
